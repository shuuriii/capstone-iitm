# %% [markdown]
# # Phase 6 Monitoring and Governance Deliverables
#
# ## Phase 6 Deliverables
#
# GitHub Repository:
#
# https://github.com/shuuriii/capstone-iitm
#
# ## Monitoring Scripts
#
# https://github.com/shuuriii/capstone-iitm/blob/main/scripts/monitor_phase6.py
#
# ## Drift Detection Report
#
# https://github.com/shuuriii/capstone-iitm/blob/main/docs/phase6/drift_detection_report.md
#
# Supporting drift outputs:
#
# - https://github.com/shuuriii/capstone-iitm/blob/main/docs/phase6/feature_drift_report.csv
# - https://github.com/shuuriii/capstone-iitm/blob/main/docs/phase6/prediction_drift_report.csv
# - https://github.com/shuuriii/capstone-iitm/blob/main/docs/phase6/data_validation_report.csv
# - https://github.com/shuuriii/capstone-iitm/blob/main/docs/phase6/audit_log_summary.csv
#
# ## Governance and Compliance Document
#
# https://github.com/shuuriii/capstone-iitm/blob/main/docs/phase6/governance_compliance.md
